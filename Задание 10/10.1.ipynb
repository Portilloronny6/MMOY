# %%
# Using the datasets module of the Scikit-learn library, generate a model dataset for a multiclass classification problem with two informative features and three classes. Ensure reproducible results.
import random
from sklearn.datasets import make_multilabel_classification

random_state = random.randint(0, 500)
X, y = make_multilabel_classification(
    n_samples=1000, n_classes=3, n_labels=2,
    allow_unlabeled=False, random_state=random_state
)

# %%
# Visualize the generated point clouds.
import matplotlib.pyplot as plt

plt.scatter(X[:, 0], X[:, 1], c=y[:, 0], s=40, cmap='viridis')
plt.show()

# %%
# Split the data set into training and test samples in the ratio 70/30.
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=random_state)

# %%
# Create a decision tree model with default parameters (ensure only reproducibility of results) and train it on the training set.
from sklearn.tree import DecisionTreeClassifier, plot_tree

tree_clf = DecisionTreeClassifier(random_state=random_state)
tree_clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=151)

# %%
# Get the predictions of the trained model for the objects of the test set. Evaluate the quality of classification using the accuracy metric both on the training and test sets.
y_pred = tree_clf.predict(X_test)

from sklearn.metrics import accuracy_score

accuracy_score(y_test, y_pred)
# Out:
# 0.5866666666666667

# %%
# Create a decision tree model with a depth of 1 and train it on the training set. Get model-predicted class labels for training and test set objects. Evaluate the quality of classification using the accuracy metric on the training and test sets.
tree_clf = DecisionTreeClassifier(max_depth=1, random_state=random_state)
tree_clf.fit(X_train, y_train)

y_pred = tree_clf.predict(X_test)

accuracy_score(y_test, y_pred)
# Out:
# 0.4633333333333333

# %%
# graph the decision tree model.
plot_tree(tree_clf, filled=True)
# Out:
# [Text(0.5, 0.75, 'X[7] <= 0.5\ngini = 0.423\nsamples = 700\nvalue = [[131, 569]\n[385, 315]\n[266, 434]]'),
#  Text(0.25, 0.25, 'gini = 0.189\nsamples = 179\nvalue = [[3, 176]\n[155, 24]\n[146, 33]]'),
#  Text(0.75, 0.25, 'gini = 0.406\nsamples = 521\nvalue = [[128, 393]\n[230, 291]\n[120, 401]]')]

# %%
# Create a decision tree model with a depth of 2 and execute with it
tree_clf = DecisionTreeClassifier(max_depth=2, random_state=random_state)
tree_clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=2, random_state=151)

# %%
# graph the decision tree model.
plot_tree(tree_clf, filled=True)
# Out:
# [Text(0.5, 0.8333333333333334, 'X[7] <= 0.5\ngini = 0.423\nsamples = 700\nvalue = [[131, 569]\n[385, 315]\n[266, 434]]'),
#  Text(0.25, 0.5, 'X[12] <= 0.5\ngini = 0.189\nsamples = 179\nvalue = [[3, 176]\n[155, 24]\n[146, 33]]'),
#  Text(0.125, 0.16666666666666666, 'gini = 0.055\nsamples = 138\nvalue = [[0, 138]\n[135, 3]\n[129, 9]]'),
#  Text(0.375, 0.16666666666666666, 'gini = 0.374\nsamples = 41\nvalue = [[3, 38]\n[20, 21]\n[17, 24]]'),
#  Text(0.75, 0.5, 'X[8] <= 0.5\ngini = 0.406\nsamples = 521\nvalue = [[128, 393]\n[230, 291]\n[120, 401]]'),
#  Text(0.625, 0.16666666666666666, 'gini = 0.298\nsamples = 102\nvalue = [[70, 32]\n[75, 27]\n[4, 98]]'),
#  Text(0.875, 0.16666666666666666, 'gini = 0.368\nsamples = 419\nvalue = [[58, 361]\n[155, 264]\n[116, 303]]')]

# %%
# Create a decision tree model with a depth of 3 and execute with it
tree_clf = DecisionTreeClassifier(max_depth=3, random_state=random_state)
tree_clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=151)

# %%
# graph the decision tree model.
plot_tree(tree_clf, filled=True)
# Out:
# [Text(0.5, 0.875, 'X[7] <= 0.5\ngini = 0.423\nsamples = 700\nvalue = [[131, 569]\n[385, 315]\n[266, 434]]'),
#  Text(0.25, 0.625, 'X[12] <= 0.5\ngini = 0.189\nsamples = 179\nvalue = [[3, 176]\n[155, 24]\n[146, 33]]'),
#  Text(0.125, 0.375, 'X[6] <= 2.5\ngini = 0.055\nsamples = 138\nvalue = [[0, 138]\n[135, 3]\n[129, 9]]'),
#  Text(0.0625, 0.125, 'gini = 0.034\nsamples = 134\nvalue = [[0, 134]\n[132, 2]\n[129, 5]]'),
#  Text(0.1875, 0.125, 'gini = 0.125\nsamples = 4\nvalue = [[0, 4]\n[3, 1]\n[0, 4]]'),
#  Text(0.375, 0.375, 'X[13] <= 1.5\ngini = 0.374\nsamples = 41\nvalue = [[3, 38]\n[20, 21]\n[17, 24]]'),
#  Text(0.3125, 0.125, 'gini = 0.117\nsamples = 16\nvalue = [[1, 15]\n[15, 1]\n[1, 15]]'),
#  Text(0.4375, 0.125, 'gini = 0.309\nsamples = 25\nvalue = [[2, 23]\n[5, 20]\n[16, 9]]'),
#  Text(0.75, 0.625, 'X[8] <= 0.5\ngini = 0.406\nsamples = 521\nvalue = [[128, 393]\n[230, 291]\n[120, 401]]'),
#  Text(0.625, 0.375, 'X[15] <= 1.5\ngini = 0.298\nsamples = 102\nvalue = [[70, 32]\n[75, 27]\n[4, 98]]'),
#  Text(0.5625, 0.125, 'gini = 0.131\nsamples = 68\nvalue = [[60, 8]\n[61, 7]\n[0, 68]]'),
#  Text(0.6875, 0.125, 'gini = 0.369\nsamples = 34\nvalue = [[10, 24]\n[14, 20]\n[4, 30]]'),
#  Text(0.875, 0.375, 'X[12] <= 1.5\ngini = 0.368\nsamples = 419\nvalue = [[58, 361]\n[155, 264]\n[116, 303]]'),
#  Text(0.8125, 0.125, 'gini = 0.292\nsamples = 201\nvalue = [[7, 194]\n[118, 83]\n[41, 160]]'),
#  Text(0.9375, 0.125, 'gini = 0.364\nsamples = 218\nvalue = [[51, 167]\n[37, 181]\n[75, 143]]')]

# %%
# Create a decision tree model with a limit on the number of objects in a sheet (specify no more than 3 objects). Train this model on the training set. Get model-predicted class labels for training and test set objects. Evaluate the classification quality using the accuracy metric on the training and test sets.
tree_clf = DecisionTreeClassifier(max_leaf_nodes=3, random_state=random_state)
tree_clf.fit(X_train, y_train)

y_pred = tree_clf.predict(X_test)

accuracy_score(y_test, y_pred)
# Out:
# 0.5166666666666667

# %%
plot_tree(tree_clf, filled=True)
# Out:
# [Text(0.4, 0.8333333333333334, 'X[7] <= 0.5\ngini = 0.423\nsamples = 700\nvalue = [[131, 569]\n[385, 315]\n[266, 434]]'),
#  Text(0.2, 0.5, 'gini = 0.189\nsamples = 179\nvalue = [[3, 176]\n[155, 24]\n[146, 33]]'),
#  Text(0.6, 0.5, 'X[8] <= 0.5\ngini = 0.406\nsamples = 521\nvalue = [[128, 393]\n[230, 291]\n[120, 401]]'),
#  Text(0.4, 0.16666666666666666, 'gini = 0.298\nsamples = 102\nvalue = [[70, 32]\n[75, 27]\n[4, 98]]'),
#  Text(0.8, 0.16666666666666666, 'gini = 0.368\nsamples = 419\nvalue = [[58, 361]\n[155, 264]\n[116, 303]]')]
